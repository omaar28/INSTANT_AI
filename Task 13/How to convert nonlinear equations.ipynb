# %% [markdown]
# # How to convert nonlinear equation to linear equation
#
# ### First solution:
#
# y = ax + b/x (time both sides by x)
#
# yx = ax^2 + b
#
# y = ax + c
#
# ![image.png](attachment:image.png)
#
# ### Alternals solution:
#
# y = ax + b/x (divide both sides by x)
#
# y/x = a + b/x^2
#
# y/x = b/x^2 + a
#
# y = mx + c
#
# ![image-2.png](attachment:image-2.png)
